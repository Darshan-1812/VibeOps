# %%
# !pip install mlflow boto3 awscli
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\DARSHAN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: mlflow in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.9.0)
# Requirement already satisfied: boto3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.42.44)
# Requirement already satisfied: awscli in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.44.34)
# Requirement already satisfied: mlflow-skinny==3.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: skops<1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.85.0)
# Requirement already satisfied: fastapi<1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.128.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (24.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.44 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from boto3) (1.42.44)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from awscli) (0.19)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from awscli) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from awscli) (4.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from botocore<1.43.0,>=1.42.44->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from botocore<1.43.0,>=1.42.44->boto3) (2.5.0)
# Requirement already satisfied: Mako in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: pywin32>=304 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: pycparser in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: wcwidth in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.44->boto3) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2025.8.3)
# Requirement already satisfied: h11>=0.8 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\darshan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.12.1)

# %%
# Configure AWS credentials using environment variables (safer for notebooks)
import os

# Set your AWS credentials here
os.environ['AWS_ACCESS_KEY_ID'] = 'your-access-key-id'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'your-secret-access-key'
os.environ['AWS_DEFAULT_REGION'] = 'us-east-1'  # Change to your region

# Or use boto3 directly
import boto3
boto3.setup_default_session(
    aws_access_key_id='your-access-key-id',
    aws_secret_access_key='your-secret-access-key',
    region_name='us-east-1'
)

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-184-72-133-224.compute-1.amazonaws.com:5000/")

# %%
mlflow.set_experiment("Exp 2 - BoW vs TfIdf")
# Out:
# <Experiment: artifact_location='s3://mlflow-darshan/2', creation_time=1770616960219, experiment_id='2', last_update_time=1770616960219, lifecycle_stage='active', name='Exp 2 - BoW vs TfIdf', tags={}>

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
df = pd.read_csv(r'E:\PROJECT_3rd\end-to-end MLops\notebook\reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Function to run the experiment
def run_experiment(vectorizer_type, ngram_range, vectorizer_max_features, vectorizer_name):
    # Step 2: Vectorization
    if vectorizer_type == "BoW":
        vectorizer = CountVectorizer(ngram_range=ngram_range, max_features=vectorizer_max_features)
    else:
        vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=vectorizer_max_features)

    X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)

    # Step 4: Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName", f"{vectorizer_name}_{ngram_range}_RandomForest")
        mlflow.set_tag("experiment_type", "feature_engineering")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag("description", f"RandomForest with {vectorizer_name}, ngram_range={ngram_range}, max_features={vectorizer_max_features}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", vectorizer_type)
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", vectorizer_max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)

        # Initialize and train the model
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(X_train, y_train)

        # Step 5: Make predictions and log metrics
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: {vectorizer_name}, {ngram_range}")
        plt.savefig("confusion_matrix.png")
        mlflow.log_artifact("confusion_matrix.png")
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(model, f"random_forest_model_{vectorizer_name}_{ngram_range}")

# Step 6: Run experiments for BoW and TF-IDF with different n-grams
ngram_ranges = [(1, 1), (1, 2), (1, 3)]  # unigrams, bigrams, trigrams
max_features = 5000  # Example max feature size

for ngram_range in ngram_ranges:
    # BoW Experiments
    run_experiment("BoW", ngram_range, max_features, vectorizer_name="BoW")

    # TF-IDF Experiments
    run_experiment("TF-IDF", ngram_range, max_features, vectorizer_name="TF-IDF")
# Out:
# 🏃 View run BoW_(1, 1)_RandomForest at: http://ec2-184-72-133-224.compute-1.amazonaws.com:5000/#/experiments/2/runs/65378382c197429a8ec81704fe9cc065
# 🧪 View experiment at: http://ec2-184-72-133-224.compute-1.amazonaws.com:5000/#/experiments/2
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\boto3\s3\transfer.py:452, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     451 try:
# --> 452     future.result()
#     453 # If a client error was raised, add the backwards compatibility layer
#     454 # that raises a S3UploadFailedError. These specific errors were only
#     455 # ever thrown for upload_parts but now can be thrown for any related
#     456 # client error.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s3transfer\futures.py:111, in TransferFuture.result(self)
#     107 try:
#     108     # Usually the result() method blocks until the transfer is done,
#     109     # however if a KeyboardInterrupt is raised we want want to exit
#     110     # out of this and propagate the exception.
# --> 111     return self._coordinator.result()
#     112 except KeyboardInterrupt as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s3transfer\futures.py:287, in TransferCoordinator.result(self)
#     286 if self._exception:
# --> 287     raise self._exception
#     288 return self._result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s3transfer\tasks.py:142, in Task.__call__(self, ctx)
#     141     if not self._transfer_coordinator.done():
# --> 142         return self._execute_main(kwargs)
#     143 except Exception as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s3transfer\tasks.py:165, in Task._execute_main(self, kwargs)
#     163 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 165 return_value = self._main(**kwargs)
#     166 # If the task is the final task, then set the TransferFuture's
#     167 # value to the return value from main().
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\s3transfer\upload.py:796, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     795 with fileobj as body:
# --> 796     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# ClientError: An error occurred (InvalidAccessKeyId) when calling the PutObject operation: The AWS Access Key Id you provided does not exist in our records.
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# Cell In[13], line 74
#      70 max_features = 5000  # Example max feature size
#      72 for ngram_range in ngram_ranges:
#      73     # BoW Experiments
# ---> 74     run_experiment("BoW", ngram_range, max_features, vectorizer_name="BoW")
#      76     # TF-IDF Experiments
#      77     run_experiment("TF-IDF", ngram_range, max_features, vectorizer_name="TF-IDF")
#
# Cell In[13], line 62, in run_experiment(vectorizer_type, ngram_range, vectorizer_max_features, vectorizer_name)
#      60 plt.title(f"Confusion Matrix: {vectorizer_name}, {ngram_range}")
#      61 plt.savefig("confusion_matrix.png")
# ---> 62 mlflow.log_artifact("confusion_matrix.png")
#      63 plt.close()
#      65 # Log the model
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mlflow\tracking\fluent.py:1533, in log_artifact(local_path, artifact_path, run_id)
#    1503 """
#    1504 Log a local file or directory as an artifact of the currently active run. If no run is
#    1505 active, this method will create a new active run.
#    (...)
#    1530             mlflow.log_artifact(path)
#    1531 """
#    1532 run_id = run_id or _get_or_start_run().info.run_id
# -> 1533 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mlflow\tracking\client.py:2652, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    2648 if run_id.startswith(TRACE_REQUEST_ID_PREFIX):
#    2649     raise MlflowException(
#    2650         f"Invalid run id: {run_id}. `log_artifact` run id must map to a valid run."
#    2651     )
# -> 2652 self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mlflow\tracking\_tracking_service\client.py:675, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     673     artifact_repo.log_artifacts(local_path, path_name)
#     674 else:
# --> 675     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mlflow\store\artifact\s3_artifact_repo.py:273, in S3ArtifactRepository.log_artifact(self, local_file, artifact_path)
#     271     dest_path = posixpath.join(dest_path, artifact_path)
#     272 dest_path = posixpath.join(dest_path, os.path.basename(local_file))
# --> 273 self._upload_file(
#     274     s3_client=self._get_s3_client(), local_file=local_file, bucket=bucket, key=dest_path
#     275 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mlflow\store\artifact\s3_artifact_repo.py:253, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     251 if environ_extra_args is not None:
#     252     extra_args.update(environ_extra_args)
# --> 253 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\boto3\s3\inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)
#     172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\boto3\s3\transfer.py:458, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     453 # If a client error was raised, add the backwards compatibility layer
#     454 # that raises a S3UploadFailedError. These specific errors were only
#     455 # ever thrown for upload_parts but now can be thrown for any related
#     456 # client error.
#     457 except ClientError as e:
# --> 458     raise S3UploadFailedError(
#     459         f"Failed to upload {filename} to {bucket}/{key}: {e}"
#     460     )
#
# S3UploadFailedError: Failed to upload confusion_matrix.png to mlflow-darshan/2/65378382c197429a8ec81704fe9cc065/artifacts/confusion_matrix.png: An error occurred (InvalidAccessKeyId) when calling the PutObject operation: The AWS Access Key Id you provided does not exist in our records.
